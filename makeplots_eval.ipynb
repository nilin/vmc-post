# %%
from config import *
from util import *

# %%
logdir=logdir+'/picks'

system='LiH'
name=system+'_SRs'
opt='(minsr|proxsr)'

runs=getruns(logdir)
runs=filter_paths(runs,'.*'+system+'.*'+opt+'.*')
runs=sortruns(runs)
ref=reference_energies[system]-.00004
printnotes(runs)
# Out:
# LiH_minsr_0.005 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_minsr_0.01 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_minsr_0.02 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_minsr_0.05 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_minsr_0.1 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_minsr_0.2 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_minsr_0.5 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_minsr_1.0 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_minsr_2.0 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_proxsr_0.005 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_proxsr_0.01 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_proxsr_0.02 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_proxsr_0.05 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_proxsr_0.1 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)
# LiH_proxsr_0.2 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/LiH/checkpoints/150.npz, new optimizer state)

# %%
labels=[cleanlabel(n) for r,n in runs.items()]
errors=[getevalenergy(logdir,r)-ref for r in runs]
colors=[get_optimizer_color(n) for r,n in runs.items()]

plt.figure(figsize=(10,5))
plt.title(name+' final energy error')
plt.barh(labels,errors,color=colors)
plt.xscale('log')
plt.tight_layout()
savefig(plotdir,'sweep_'+name)
# Out:
# /Users/nilin2/Library/CloudStorage/GoogleDrive-nilin@berkeley.edu/My Drive/vmcdata/plots/sweep_LiH_SRs.pdf
