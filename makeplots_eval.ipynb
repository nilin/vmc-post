# %%
from config import *
from util import *

# %%
logdir=logdir+'/10_12'

system='H4'
name=system
opt='proxsr'

runs=getruns(logdir)
runs=filter_paths(runs,'.*'+system+'.*'+opt+'.*')
runs=sortruns(runs)
ref=reference_energies[system]-.00004
printnotes(runs)
# Out:
# H4_minsr_0.005 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/H4/checkpoints/150.npz, new optimizer state)
# H4_minsr_0.01 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/H4/checkpoints/150.npz, new optimizer state)
# H4_minsr_0.02 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/H4/checkpoints/150.npz, new optimizer state)
# H4_minsr_0.05 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/H4/checkpoints/150.npz, new optimizer state)
# H4_proxsr_0.005 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/1000.npz, new optimizer state)
# H4_proxsr_0.005 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/2000.npz, new optimizer state)
# H4_proxsr_0.005 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/H4/checkpoints/150.npz, new optimizer state)
# H4_proxsr_0.005 (reloaded from /global/scratch/users/nilin/warmstarts_10_4/H4/checkpoints/100.npz, new optimizer state)
# H4_proxsr_0.01 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/1000.npz, new optimizer state)
# H4_proxsr_0.01 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/2000.npz, new optimizer state)
# H4_proxsr_0.01 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/H4/checkpoints/150.npz, new optimizer state)
# H4_proxsr_0.01 (reloaded from /global/scratch/users/nilin/warmstarts_10_4/H4/checkpoints/100.npz, new optimizer state)
# H4_proxsr_0.02 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/1000.npz, new optimizer state)
# H4_proxsr_0.02 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/2000.npz, new optimizer state)
# H4_proxsr_0.02 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/H4/checkpoints/150.npz, new optimizer state)
# H4_proxsr_0.02 (reloaded from /global/scratch/users/nilin/warmstarts_10_4/H4/checkpoints/100.npz, new optimizer state)
# H4_proxsr_0.05 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/1000.npz, new optimizer state)
# H4_proxsr_0.05 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/2000.npz, new optimizer state)
# H4_proxsr_0.05 (reloaded from /global/scratch/users/nilin/warm_starts_10000/H4/checkpoints/1000.npz, new optimizer state)
# H4_proxsr_0.05 (reloaded from /global/scratch/users/nilin/warm_starts_10_12/H4/checkpoints/150.npz, new optimizer state)
# H4_proxsr_0.05 (reloaded from /global/scratch/users/nilin/warmstarts_10_4/H4/checkpoints/100.npz, new optimizer state)
# H4_proxsr_0.10 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/1000.npz, new optimizer state)
# H4_proxsr_0.10 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/2000.npz, new optimizer state)
# H4_proxsr_0.10 (reloaded from /global/scratch/users/nilin/warmstarts_10_4/H4/checkpoints/100.npz, new optimizer state)
# H4_proxsr_0.20 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/1000.npz, new optimizer state)
# H4_proxsr_0.20 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/2000.npz, new optimizer state)
# H4_proxsr_0.50 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/1000.npz, new optimizer state)
# H4_proxsr_0.50 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/2000.npz, new optimizer state)
# H4_proxsr_0.50 (reloaded from /global/scratch/users/nilin/warmstarts_10_4/H4/checkpoints/100.npz, new optimizer state)
# H4_proxsr_1.00 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/1000.npz, new optimizer state)
# H4_proxsr_1.00 (reloaded from /global/scratch/users/nilin/logs/H4/checkpoints/2000.npz, new optimizer state)
# H4_proxsr_1.00 (reloaded from /global/scratch/users/nilin/warmstarts_10_4/H4/checkpoints/100.npz, new optimizer state)

# %%
labels=[cleanlabel(n) for r,n in runs.items()]
errors=[getevalenergy(logdir,r)-ref for r in runs]
colors=[get_optimizer_color(n) for r,n in runs.items()]

plt.figure(figsize=(10,5))
plt.title(name+' final energy error')
plt.barh(labels,errors,color=colors)
#plt.xscale('log')
plt.tight_layout()
savefig('plots/sweep/'+name)
